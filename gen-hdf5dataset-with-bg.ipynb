# %%
# !pip install -q h5py
# !pip install -q Pillow
# !pip install -q ipyplot
# Out:
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3 -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3 -m pip install --upgrade pip' command.
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
import h5py
import ipyplot
import numpy as np
from PIL import Image

# %%
data = None
base_path = "datasets/demo-chair-with-bg/images/"
filename = "datasets/demo-chair-with-bg/data_chair.hdf5"

# %%
# clear the old one
if os.path.exists(filename):
  os.remove(filename)

# %%
h5 = h5py.File(filename, "a")

for i in os.listdir(base_path):
  img_path = os.path.join(base_path, i)
  img_name = i.split('.')[0]
  img_pose = img_name.split('_')[1:]
  img_pose = [int(img_pose[0]), int(img_pose[1])]
  print('image:', img_name)
  print('pose:', img_pose)

  # create group by image name
  img_group = h5.create_group(img_name)

  # add image
  img_group.create_dataset('image', data=np.asarray(Image.open(img_path)))

  # add pose
  img_group.create_dataset('pose', data=img_pose)

h5.close()
# Out:
# image: 11c9c57efad0b5ec297936c81e7f6629_28_10
# pose: [28, 10]
# image: 11c9c57efad0b5ec297936c81e7f6629_12_10
# pose: [12, 10]
# image: 11c9c57efad0b5ec297936c81e7f6629_34_10
# pose: [34, 10]
# image: 11c9c57efad0b5ec297936c81e7f6629_10_10
# pose: [10, 10]
# image: 11c9c57efad0b5ec297936c81e7f6629_4_10
# pose: [4, 10]

# %%
f = h5py.File(filename, 'r')

# %%
# List all groups
keys = list(f.keys())
print("Example keys (sampling first 10-keys): %s\n" % keys[:10])
# Out:
# Example keys (sampling first 10-keys): ['11c9c57efad0b5ec297936c81e7f6629_10_10', '11c9c57efad0b5ec297936c81e7f6629_12_10', '11c9c57efad0b5ec297936c81e7f6629_28_10', '11c9c57efad0b5ec297936c81e7f6629_34_10', '11c9c57efad0b5ec297936c81e7f6629_4_10']

# %%
group = f['11c9c57efad0b5ec297936c81e7f6629_4_10']

# %%
list(group.keys())
# Out:
# ['image', 'pose']

# %%
group['pose'][()]
# Out:
# array([ 4, 10])

# %%
data = group['image'][()]

# %%
# data
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
Image.fromarray(data)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F95ADF3BD90>

# %%
num_img = 200
max_img = num_img
count_img = 0
img_arr = []

for key in keys:
    if count_img == num_img:
        break
        
    each_group = f[key]
    data = each_group['image'][()]
    img_arr.append(data)
    count_img = count_img + 1

ipyplot.plot_images(img_arr, max_images=max_img, img_width=150)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-X6V9Ui9rDbRHpLsJRbXRnk {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-X6V9Ui9rDbRHpLsJRbXRnk {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-X6V9Ui9rDbRHpLsJRbXRnk {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-X6V9Ui9rDbRHpLsJRbXRnk:checked ~ #ipyplot-html-viewer-textarea-X6V9Ui9rDbRHpLsJRbXRnk {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-X6V9Ui9rDbRHpLsJRbXRnk:checked + #ipyplot-html-viewer-label-X6V9Ui9rDbRHpLsJRbXRnk:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-X6V9Ui9rDbRHpLsJRbXRnk">
#         <label id="ipyplot-html-viewer-label-X6V9Ui9rDbRHpLsJRbXRnk" for="ipyplot-html-viewer-toggle-X6V9Ui9rDbRHpLsJRbXRnk">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-X6V9Ui9rDbRHpLsJRbXRnk" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-7j6ctKmykDmp6bz7egf5Z9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7j6ctKmykDmp6bz7egf5Z9">
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-FKk25VLeaczoNBVcdL5sbv" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-FKk25VLeaczoNBVcdL5sbv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-Z7VGajVvKbQavKR9w6HHyq" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-Z7VGajVvKbQavKR9w6HHyq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-KTpNPvvhWc4FGXZeUqxHxQ" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-KTpNPvvhWc4FGXZeUqxHxQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-hwrfgrFx3Q4aPKUufCcUCb" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-hwrfgrFx3Q4aPKUufCcUCb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-AXYubgpNPLh8b7rmuuGx3s" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-AXYubgpNPLh8b7rmuuGx3s">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-7j6ctKmykDmp6bz7egf5Z9 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-7j6ctKmykDmp6bz7egf5Z9">
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-FKk25VLeaczoNBVcdL5sbv" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-FKk25VLeaczoNBVcdL5sbv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-Z7VGajVvKbQavKR9w6HHyq" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-Z7VGajVvKbQavKR9w6HHyq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-KTpNPvvhWc4FGXZeUqxHxQ" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-KTpNPvvhWc4FGXZeUqxHxQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-hwrfgrFx3Q4aPKUufCcUCb" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-hwrfgrFx3Q4aPKUufCcUCb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-7j6ctKmykDmp6bz7egf5Z9">
#         <div id="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-AXYubgpNPLh8b7rmuuGx3s" class="ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-7j6ctKmykDmp6bz7egf5Z9-AXYubgpNPLh8b7rmuuGx3s">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
test_group = f['11c9c57efad0b5ec297936c81e7f6629_34_10']
test_data = test_group['image'][()]
Image.fromarray(test_data)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F95ADEA8B10>

# %%
f.close()
